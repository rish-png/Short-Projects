# %% [markdown]
# # Image Classification with CNN using Keras

# %% [markdown]
# # Task 1: Import Libraries

# %%
import tensorflow as tf
import os
import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

if not os.path.isdir('models'):
    os.mkdir('models')
    
print('TensorFlow version:', tf.__version__)
print('Number of GPUs available : ', 
      len(tf.config.list_physical_devices('GPU')))
# Out:
# TensorFlow version: 2.4.0
# Number of GPUs available :  1

# %% [markdown]
# # Preprocess Data

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train, x_test = x_train/255.0, x_test/255.0
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (50000, 32, 32, 3) (50000, 10)
# (10000, 32, 32, 3) (10000, 10)

# %% [markdown]
# # Visualize Examples

# %%
class_names = ['aeroplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
def show_random_examples(x, y, p):
    idx = np.random.choice(range(x.shape[0]), 10, replace=True)
    
    x = x[idx]
    y = y[idx]
    p = p[idx]
    
    plt.figure(figsize=(10,5))
    for i in range(10):
        plt.subplot(2,5, i+1)
        plt.imshow(x[i])
        col = 'green' if np.argmax(y[i], axis=0) == np.argmax(p[i], axis=0) else 'red'
        plt.xticks([])
        plt.yticks([])
        plt.xlabel(class_names[np.argmax(p[i], axis=0)], color=col)

# %%
show_random_examples(x_train, y_train, y_train)

# %% [markdown]
# # Model Creation

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.layers import Dropout, Flatten, Input, Dense
from tensorflow.keras.models import Sequential

# %%
def create_model():
    model = Sequential()
    model.add(Input(shape=(32,32,3)))
    model.add(Conv2D(24,kernel_size=(3,3),padding='same',activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(24,kernel_size=(3,3),padding='same',activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(32,kernel_size=5,strides=2,padding='same',activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(Conv2D(64,(3,3),activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(64,kernel_size=5,strides=2,padding='same',activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(Conv2D(128,kernel_size=4,activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(256,kernel_size=3,activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(512,kernel_size=2,activation='relu'))
    model.add(BatchNormalization())
    model.add(Flatten())
    model.add(Dropout(0.4))
    model.add(Dense(10,activation='softmax'))
    
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 24)        672
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 24)        96
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 24)        5208
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 24)        96
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        19232
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 64)          102464
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 7, 7, 64)          256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 128)         131200
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 4, 4, 128)         512
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 2, 2, 256)         295168
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 2, 2, 256)         1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 1, 512)         524800
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 1, 1, 512)         2048
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                5130
# =================================================================
# Total params: 1,106,786
# Trainable params: 1,104,578
# Non-trainable params: 2,208
# _________________________________________________________________

# %% [markdown]
# # Training the model

# %%
hist = model.fit(x_train, y_train, batch_size=512,
                 epochs=20, validation_split=0.1,
                callbacks=[
                    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3),
                    tf.keras.callbacks.ModelCheckpoint(
                        'models/model_{val_accuracy:.3f}.h5',
                        monitor='val_accuracy',
                        save_best_only=True, save_weights_only=False)
                ])
# Out:
# Epoch 1/20
# 88/88 [==============================] - 14s 63ms/step - loss: 2.4012 - accuracy: 0.2758 - val_loss: 2.8655 - val_accuracy: 0.0958
# Epoch 2/20
# 88/88 [==============================] - 4s 49ms/step - loss: 1.5076 - accuracy: 0.4701 - val_loss: 2.8274 - val_accuracy: 0.1930
# Epoch 3/20
# 88/88 [==============================] - 4s 50ms/step - loss: 1.2490 - accuracy: 0.5615 - val_loss: 2.6804 - val_accuracy: 0.2382
# Epoch 4/20
# 88/88 [==============================] - 4s 50ms/step - loss: 1.0692 - accuracy: 0.6235 - val_loss: 2.6050 - val_accuracy: 0.2454
# Epoch 5/20
# 88/88 [==============================] - 4s 50ms/step - loss: 0.9600 - accuracy: 0.6664 - val_loss: 1.6945 - val_accuracy: 0.4544
# Epoch 6/20
# 88/88 [==============================] - 4s 50ms/step - loss: 0.8586 - accuracy: 0.6996 - val_loss: 1.1720 - val_accuracy: 0.6032
# Epoch 7/20
# 88/88 [==============================] - 4s 51ms/step - loss: 0.7616 - accuracy: 0.7284 - val_loss: 0.7839 - val_accuracy: 0.7230
# Epoch 8/20
# 88/88 [==============================] - 4s 51ms/step - loss: 0.6863 - accuracy: 0.7554 - val_loss: 0.7747 - val_accuracy: 0.7366
# Epoch 9/20
# 88/88 [==============================] - 5s 51ms/step - loss: 0.6407 - accuracy: 0.7707 - val_loss: 0.7657 - val_accuracy: 0.7448
# Epoch 10/20
# 88/88 [==============================] - 4s 51ms/step - loss: 0.5932 - accuracy: 0.7933 - val_loss: 0.7272 - val_accuracy: 0.7542
# Epoch 11/20
# 88/88 [==============================] - 5s 51ms/step - loss: 0.5444 - accuracy: 0.8057 - val_loss: 0.6926 - val_accuracy: 0.7688
# Epoch 12/20
# 88/88 [==============================] - 5s 51ms/step - loss: 0.4947 - accuracy: 0.8221 - val_loss: 0.6338 - val_accuracy: 0.7956
# Epoch 13/20
# 88/88 [==============================] - 5s 52ms/step - loss: 0.4558 - accuracy: 0.8368 - val_loss: 0.6354 - val_accuracy: 0.7930
# Epoch 14/20
# 88/88 [==============================] - 5s 52ms/step - loss: 0.4319 - accuracy: 0.8453 - val_loss: 0.6873 - val_accuracy: 0.7810
# Epoch 15/20
# 88/88 [==============================] - 5s 53ms/step - loss: 0.3962 - accuracy: 0.8577 - val_loss: 0.6222 - val_accuracy: 0.8018
# Epoch 16/20
# 88/88 [==============================] - 5s 53ms/step - loss: 0.3646 - accuracy: 0.8681 - val_loss: 0.6674 - val_accuracy: 0.7908
# Epoch 17/20
# 88/88 [==============================] - 5s 53ms/step - loss: 0.3484 - accuracy: 0.8746 - val_loss: 0.6423 - val_accuracy: 0.8024
# Epoch 18/20
# 88/88 [==============================] - 5s 53ms/step - loss: 0.3207 - accuracy: 0.8861 - val_loss: 0.6366 - val_accuracy: 0.8116
# Epoch 19/20
# 88/88 [==============================] - 5s 52ms/step - loss: 0.2943 - accuracy: 0.8956 - val_loss: 0.6927 - val_accuracy: 0.8036
# Epoch 20/20
# 88/88 [==============================] - 5s 53ms/step - loss: 0.2709 - accuracy: 0.9040 - val_loss: 0.6865 - val_accuracy: 0.8028

# %% [markdown]
# # Predictions

# %%
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']

plt.plot(range(len(acc)), acc, label='Training')
plt.plot(range(len(acc)), val_acc, label='Validation')
plt.legend()

# %%
model = tf.keras.models.load_model('models/model_0.812.h5')

# %%
_, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy : {test_acc*100:.2f} %")
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6745 - accuracy: 0.7922
# Test Accuracy : 79.22 %

# %%
x_test_pred = model.predict(x_test)

# %%
show_random_examples(x_test, y_test, x_test_pred)
